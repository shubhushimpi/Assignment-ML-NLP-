# %% [markdown]
# ### <font color=purple>Plottings with pandas data frames

# %% [markdown]
# ### Importing Libraries

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
#Load the Datasets
car_sales = pd.read_csv('car-sales.csv')
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
ts = pd.Series(np.random.randn(100).astype(int),
              index = pd.date_range("1/1/2020",periods = 100))
ts = ts.cumsum()
ts.plot();

# %% [markdown]
# ### Plotting Using a Dataset

# %%
car_sales['Price'] = car_sales['Price'].str.replace('[\$\,\.]','')
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
#Remove the last two zeros
car_sales['Price']= car_sales['Price'].str[:-2]
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_sales['Price']=car_sales['Price'].astype(int)
#Adding a new Column
car_sales['Sales Date'] = pd.date_range("1/1/2020",periods = len(car_sales))
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price Sales Date
# 0  Toyota  White         150043      4   4000 2020-01-01
# 1   Honda    Red          87899      4   5000 2020-01-02
# 2  Toyota   Blue          32549      3   7000 2020-01-03
# 3     BMW  Black          11179      5  22000 2020-01-04
# 4  Nissan  White         213095      4   3500 2020-01-05
# 5  Toyota  Green          99213      4   4500 2020-01-06
# 6   Honda   Blue          45698      4   7500 2020-01-07
# 7   Honda   Blue          54738      4   7000 2020-01-08
# 8  Toyota  White          60000      4   6250 2020-01-09
# 9  Nissan  White          31600      4   9700 2020-01-10

# %%
car_sales['Total Sales'] = car_sales['Price'].cumsum()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price Sales Date  Total Sales
# 0  Toyota  White         150043      4   4000 2020-01-01         4000
# 1   Honda    Red          87899      4   5000 2020-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2020-01-03        16000
# 3     BMW  Black          11179      5  22000 2020-01-04        38000
# 4  Nissan  White         213095      4   3500 2020-01-05        41500
# 5  Toyota  Green          99213      4   4500 2020-01-06        46000
# 6   Honda   Blue          45698      4   7500 2020-01-07        53500
# 7   Honda   Blue          54738      4   7000 2020-01-08        60500
# 8  Toyota  White          60000      4   6250 2020-01-09        66750
# 9  Nissan  White          31600      4   9700 2020-01-10        76450

# %% [markdown]
# ### Line plot

# %%
#Lets plot the Total Sales
car_sales.plot(x='Sales Date',y='Total Sales');

# %% [markdown]
# ### Scatter Plot

# %%
#Plotting scatterplot with price column and odometer
car_sales.plot(x="Odometer (KM)", y="Price", kind = "scatter");

# %% [markdown]
# ### Bar plot

# %%
#Plotting barplot 
car_sales.plot(x = "Make", y ="Price", kind = "bar");

# %% [markdown]
# ### Histogram

# %%
car_sales['Odometer (KM)'].plot.hist();
#Another way 
#car_sales['Odometer (KM)'].plot(kind = 'hist');

# %%
#Changing the bins number
car_sales['Odometer (KM)'].plot.hist(bins = 20);

# %%
#Lets do ot with another dataset
heart_disease = pd.read_csv('heart-disease.csv')
heart_disease.head(10)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
# 7   44    1   1       120   263    0        1      173      0      0.0      2
# 8   52    1   2       172   199    1        1      162      0      0.5      2
# 9   57    1   2       150   168    0        1      174      0      1.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# ...

# %%
#Create a histogram of age
heart_disease['age'].plot.hist(bins = 20);

# %%
heart_disease.plot.hist(subplots = True,figsize = (20,30)); #Histograms of entire dataset

# %% [markdown]
# ### Which one should we use (pyplot vs matplotlib OO method)?
#  * when plotting something quick, we can use pyplot method.
#  * when plotting something advance use OO method.

# %%
over_50 = heart_disease[heart_disease["age"] > 50]
over_50.head(10)
# Out:
#     age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    63    1   3       145   233    1        0      150      0      2.3
# 3    56    1   1       120   236    0        1      178      0      0.8
# 4    57    0   0       120   354    0        1      163      1      0.6
# 5    57    1   0       140   192    0        1      148      0      0.4
# 6    56    0   1       140   294    0        0      153      0      1.3
# 8    52    1   2       172   199    1        1      162      0      0.5
# 9    57    1   2       150   168    0        1      174      0      1.6
# 10   54    1   0       140   239    0        1      160      0      1.2
# 13   64    1   3       110   211    0        0      144      1      1.8
# 14   58    0   3       150   283    1        0      162      0      1.0
#
#     slope  ca  thal  target
# 0       0   0     1       1
# 3       2   0     2       1
# 4       2   0     2       1
# 5       1   0     1       1
# 6       1   0     2       1
# ...

# %%
#PyPlot Method
over_50.plot(kind = 'scatter', 
              x = 'age',
              y= 'chol',
              c='target',
            figsize = (10,6));

# %%
#OO Method mix with pyplot
fig , ax = plt.subplots(figsize = (10,6))
over_50.plot(kind= 'scatter',
            x = 'age',
            y = 'chol',
            c = 'target',
            ax=ax);
#Setting the limitation of the axes
ax.set_xlim([45,100]);

# %%
#OO Method from scratch

fig , ax = plt.subplots(figsize =(10,6))

#plot the data
scatter = ax.scatter(x = over_50['age'],
                    y = over_50['chol'],
                    c = over_50['target']);

#Customize your plots
ax.set(title = 'Heart Disease and Cholesterol levels',
      xlabel = 'Age',
      ylabel= 'Cholesterol');

#Add a legend
ax.legend(*scatter.legend_elements(), title="Target");

#Add a horizontol line
ax.axhline(over_50['chol'].mean(),
          linestyle='--');

# %%
#Subplots of chol,age and thalach
fig , (ax0,ax1) = plt.subplots(nrows = 2,
                               ncols=1,
                               figsize = (10,10),
                              sharex= True)

#Add data to ax0
scatter = ax0.scatter( x = over_50['age'],
                      y = over_50['chol'],
                     c = over_50['target'])

#Customize ax0
ax0.set(title = 'Heart Disease and Cholesterol levels',
       ylabel = 'Cholesterol');
#Add a legend
ax0.legend(*scatter.legend_elements(), title = 'Target')
# Add a mean line
ax0.axhline(over_50['chol'].mean(),
           linestyle = '--');
#######################################
#Add data to ax1
scatter = ax1.scatter(x = over_50['age'],
                      y = over_50['thalach'],
                     c = over_50['target'])
#Customise ax1
ax1.set(title = 'Heart Disease and Max Heart Rate',
       xlabel = ' Age',
       ylabel = 'Max heart Rate');

#Add a legend
ax1.legend(*scatter.legend_elements(),title = 'Target')

#Add a mean line
ax1.axhline(over_50['thalach'].mean(),
           linestyle ='--');


#Add a title to the figure
fig.suptitle('Heart Disease Analysis', fontsize = '16', fontweight='bold');

# %% [markdown]
# ### Customizing Matplotlib plots with Different styles

# %%
#Different styles available
plt.style.available
# Out:
# ['bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark-palette',
#  'seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'seaborn',
#  'Solarize_Light2',
#  'tableau-colorblind10',
#  '_classic_test']

# %%
car_sales['Price'].plot();

# %%
plt.style.use('seaborn');

# %%
car_sales['Price'].plot();

# %%
plt.style.use('seaborn')

# %%
car_sales.plot( x = "Make", y = "Price",kind ="bar");

# %%
plt.style.use('fivethirtyeight')

# %%
car_sales['Price'].plot();

# %%
#Create some Data
x = np.random.randn(10,4)
x
#Dataframe
df = pd.DataFrame(x,columns = ('a','b','c','d'))
df
# Out:
#           a         b         c         d
# 0 -0.082599  1.820876  0.362802  0.988485
# 1 -1.029543 -0.432523  0.297962 -1.578861
# 2  0.327251  0.052303  0.768277  0.138240
# 3  0.552533  1.234302 -0.150877  1.150164
# 4 -0.918953  0.696777  0.795773 -0.482402
# 5 -0.438941  0.577119  1.549814 -0.247694
# 6 -0.028794  1.487312 -0.545593 -0.625924
# 7  0.602048 -0.434689  0.525301 -0.495430
# 8  0.392336 -1.504666 -0.016434 -0.041765
# 9  1.459278 -1.986224 -0.724801 -1.099784

# %%
ax =  df.plot(kind='bar')

# %%
#Customise our plots
ax=df.plot(kind = 'bar')

#Add some labels and a title
ax.set(title = 'Random number Bar Graph',
      xlabel = 'Row Number',
      ylabel='Random Number')

#Legend Visibility
ax.legend().set_visible(True)

# %%
plt.style.use('seaborn-whitegrid')

#OO Method from scratch

fig , ax = plt.subplots(figsize =(10,6))

#plot the data
scatter = ax.scatter(x = over_50['age'],
                    y = over_50['chol'],
                    c = over_50['target'],
                    cmap ='Dark2') #changes the colour 

#Customize your plots
ax.set(title = 'Heart Disease and Cholesterol levels',
      xlabel = 'Age',
      ylabel= 'Cholesterol');

#Add a legend
ax.legend(*scatter.legend_elements(), title="Target");

#Add a horizontol line
ax.axhline(over_50['chol'].mean(),
          linestyle='--');

# %%
#Subplots of chol,age and thalach
fig , (ax0,ax1) = plt.subplots(nrows = 2,
                               ncols=1,
                               figsize = (6,10),
                              sharex= True)

#Add data to ax0
scatter = ax0.scatter( x = over_50['age'],
                      y = over_50['chol'],
                     c = over_50['target'],
                     cmap='winter')

#Customize ax0
ax0.set(title = 'Heart Disease and Cholesterol levels',
       ylabel = 'Cholesterol');

#Customizing the axis
ax0.set_xlim([50,80])
ax0.set_ylim([60,400])

#Add a legend
ax0.legend(*scatter.legend_elements(), title = 'Target')
# Add a mean line
ax0.axhline(over_50['chol'].mean(),
           linestyle = '--');

#######################################
#Add data to ax1
scatter = ax1.scatter(x = over_50['age'],
                      y = over_50['thalach'],
                     c = over_50['target'],
                     cmap='winter')
#Customise ax1
ax1.set(title = 'Heart Disease and Max heart Rate',
       xlabel = ' Age',
       ylabel = 'Max heart Rate');

#Customizing the axis
ax1.set_ylim([60,200])

#Add a legend
ax1.legend(*scatter.legend_elements(),title = 'Target')

#Add a mean line
ax1.axhline(over_50['thalach'].mean(),
           linestyle ='--');


#Add a title to the figure
fig.suptitle('Heart Disease Analysis', fontsize = '16', fontweight='bold');

# %%
#To save a Particular plot in working directory
fig.savefig('heart Disease plot')
