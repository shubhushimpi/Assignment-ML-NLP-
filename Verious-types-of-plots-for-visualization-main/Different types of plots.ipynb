# %% [markdown]
# ## Different kinds of plots

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x = [1,5,10]
y = [3,4,8]

plt.plot(x,y)

# %%
plt.plot(x,y)

# %%
fig = plt.figure(figsize=(15,3))

plt.plot(x,y)
plt.xlim(0,20)
plt.ylim(0,5)
plt.xlabel('X')
plt.ylabel('Y')
plt.title('My First Graph')
# Out:
# Text(0.5, 1.0, 'My First Graph')

# %%
x = [1,8,5]
y = [2,3,6]
plt.plot (x,y)

# %%
x = [1,8,5]
y = [2,3,6]
fig = plt.figure(figsize=(4,4))
plt.plot (x,y)
plt.xlim(0,10)
plt.ylim(0,10)
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Line plot')
# Out:
# Text(0.5, 1.0, 'Line plot')

# %%
fig.get_size_inches()
# Out:
# array([4., 4.])

# %%
fig.set_size_inches(10,5)

# %%
fig

# %%
titanic = pd.read_csv ('/Users/lalitmehendiratta/Downloads/train.csv')

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
titanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
titanic.Age.max()
# Out:
# 80.0

# %%
titanic.Age.mean()
# Out:
# 29.69911764705882

# %%
titanic.Age.median()
# Out:
# 28.0

# %%
titanic.Age.mode()
# Out:
# 0    24.0
# dtype: float64

# %%
titanic.Age
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
titanic.Age.head(10)
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# 5     NaN
# 6    54.0
# 7     2.0
# 8    27.0
# 9    14.0
# Name: Age, dtype: float64

# %%
titanic.Sex.value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
titanic.Survived.value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
titanic.Embarked.value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
titanic.shape
# Out:
# (891, 12)

# %%
pd.crosstab(titanic.Survived, titanic.Sex)
# Out:
# Sex       female  male
# Survived
# 0             81   468
# 1            233   109

# %%
pd.crosstab(titanic.Survived, titanic.Sex).plot(kind='bar')

# %%
titanic.Sex.value_counts().plot(kind='pie')

# %%
sns.boxplot(x='Survived', y="Age",  data=titanic)

# %%
sns.pairplot(titanic)

# %%
sns.pairplot(titanic.iloc[:,0:6])

# %%
plt.scatter(titanic.Age, titanic.Survived)

# %%
plt.hist(titanic.Age, color='red', edgecolor= 'blue', bins = 5)
plt.xlabel('Age')
plt.ylabel('No of passensgers')
plt.title('Histogram of Age')
# Out:
# Text(0.5, 1.0, 'Histogram of Age')

# %%
plt.boxplot(titanic.Parch)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f8324ddef90>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f8324de6a90>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f8324aef810>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f8324dee510>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f8324deea10>],
#  'means': []}

# %%
plt.violinplot(titanic.Fare)
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x7f8325b359d0>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x7f8325be7490>,
#  'cmins': <matplotlib.collections.LineCollection at 0x7f8325b35ad0>,
#  'cbars': <matplotlib.collections.LineCollection at 0x7f8325b35fd0>}

# %%
xx = pd.DataFrame(index = ['aa', 'bb', 'cc', 'dd', 'ee'], 
                  data={'Apples':[20,10,15,25,18],
                        'Oranges':[12,22,17,24,20]})

# %%
xx
# Out:
#     Apples  Oranges
# aa      20       12
# bb      10       22
# cc      15       17
# dd      25       24
# ee      18       20

# %%
ax = xx.plot.bar(figsize=(15,4), color =['0.8','0.2'])

# %%
ax = xx.plot.kde(figsize=(15,4))

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(16,4))
fig.suptitle('Two Variable Plots')
xx.plot.line(ax=ax1)
xx.plot.scatter(ax=ax2, x='Apples', y='Oranges', title='Scatter plot')
xx.plot.bar(ax=ax3, title='Bar plot')

# %% [markdown]
# ###
